# %% [markdown]
# <a href="https://colab.research.google.com/github/stefaniemeliss/IADS_SC_2022_Python/blob/main/Exercise_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv

# %%
with open('avocado.csv') as csvfile:
        readCSV = csv.DictReader(csvfile, delimiter=',')
        avocadosales = []
        for col in readCSV:
            print(col['Date'],col['AveragePrice'], col['Total Volume'], col['Total Bags'],col['Small Bags'],col['Large Bags'],col['XLarge Bags'], col['year'],col['region'] )
# Out:
# Streaming output truncated to the last 5000 lines.
# 2016-09-04 1.52 139031.27 81085.75 45683.66 35402.09 0.0 2016 Midsouth
# 2016-08-28 1.51 121291.96 65369.43 36632.95 28736.48 0.0 2016 Midsouth
# 2016-08-21 1.65 122874.61 62174.65 46959.29 15215.36 0.0 2016 Midsouth
# 2016-08-14 1.62 112079.18 48563.51 32201.94 16361.57 0.0 2016 Midsouth
# 2016-08-07 1.49 134739.2 64412.96 33686.14 30726.82 0.0 2016 Midsouth
# 2016-07-31 1.56 113650.17 51029.16 32863.37 18165.79 0.0 2016 Midsouth
# 2016-07-24 1.75 103128.79 39620.46 32405.39 7215.07 0.0 2016 Midsouth
# 2016-07-17 1.59 118719.38 61009.83 36568.73 24441.1 0.0 2016 Midsouth
# 2016-07-10 1.6 105955.43 46608.83 28960.77 17648.06 0.0 2016 Midsouth
# 2016-07-03 1.52 106192.85 50143.29 27090.98 23052.31 0.0 2016 Midsouth
# 2016-06-26 1.51 106015.19 51669.19 29798.55 21870.64 0.0 2016 Midsouth
# 2016-06-19 1.36 112443.19 56497.7 26422.55 30075.15 0.0 2016 Midsouth
# 2016-06-12 1.46 112023.04 54715.7 31064.03 23651.67 0.0 2016 Midsouth
# ...

# %%
import pandas as pd

# %%
# read in data using pandas

df = pd.read_csv('/content/avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...
